# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
all_files = [file for file in os.listdir('./Sales_Data')]
all_data = pd.DataFrame()
for file in all_files:
    df = pd.read_csv('./Sales_Data/' + file)
    all_data = pd.concat([all_data,df])

# %%
all_data.to_csv('all_data.csv',index=False)

# %%
raw_data = pd.read_csv('./all_data.csv')
raw_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   236670            Wired Headphones                2      11.99
# 1   236671  Bose SoundSport Headphones                1      99.99
# 2   236672                      iPhone                1      700.0
# 3   236673       AA Batteries (4-pack)                2       3.84
# 4   236674       AA Batteries (4-pack)                2       3.84
#
#        Order Date                      Purchase Address
# 0  08/31/19 22:21      359 Spruce St, Seattle, WA 98101
# 1  08/15/19 15:11        492 Ridge St, Dallas, TX 75001
# 2  08/06/19 14:40        149 7th St, Portland, OR 97035
# 3  08/29/19 20:59     631 2nd St, Los Angeles, CA 90001
# 4  08/15/19 19:53  736 14th St, New York City, NY 10001

# %%
raw_data['Month'] = raw_data['Order Date'].str[0:2]
raw_data = raw_data.dropna(how='all')
raw_data
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        236670            Wired Headphones                2      11.99
# 1        236671  Bose SoundSport Headphones                1      99.99
# 2        236672                      iPhone                1      700.0
# 3        236673       AA Batteries (4-pack)                2       3.84
# 4        236674       AA Batteries (4-pack)                2       3.84
# ...         ...                         ...              ...        ...
# 186845   176554    Lightning Charging Cable                1      14.95
# 186846   176555            27in FHD Monitor                1     149.99
# 186847   176556      AAA Batteries (4-pack)                3       2.99
# 186848   176557                      iPhone                1        700
# 186849   176557    Lightning Charging Cable                1      14.95
#
#             Order Date                           Purchase Address Month
# 0       08/31/19 22:21           359 Spruce St, Seattle, WA 98101    08
# 1       08/15/19 15:11             492 Ridge St, Dallas, TX 75001    08
# 2       08/06/19 14:40             149 7th St, Portland, OR 97035    08
# 3       08/29/19 20:59          631 2nd St, Los Angeles, CA 90001    08
# 4       08/15/19 19:53       736 14th St, New York City, NY 10001    08
# ...                ...                                        ...   ...
# 186845  03/24/19 11:14       672 12th St, San Francisco, CA 94016    03
# 186846  03/22/19 20:27         42 4th St, San Francisco, CA 94016    03
# 186847  03/14/19 10:29          871 7th St, Los Angeles, CA 90001    03
# 186848  03/30/19 12:32  83 Washington St, San Francisco, CA 94016    03
# 186849  03/30/19 12:32  83 Washington St, San Francisco, CA 94016    03
#
# [186305 rows x 7 columns]

# %%
raw_data = raw_data[raw_data['Order Date'].str[0:2] != 'Or']
raw_data['Quantity Ordered'] = pd.to_numeric(raw_data['Quantity Ordered'])
raw_data['Price Each'] = pd.to_numeric(raw_data['Price Each'])
raw_data['Month'] = raw_data['Month'].astype('int32')
raw_data
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        236670            Wired Headphones                 2       11.99
# 1        236671  Bose SoundSport Headphones                 1       99.99
# 2        236672                      iPhone                 1      700.00
# 3        236673       AA Batteries (4-pack)                 2        3.84
# 4        236674       AA Batteries (4-pack)                 2        3.84
# ...         ...                         ...               ...         ...
# 186845   176554    Lightning Charging Cable                 1       14.95
# 186846   176555            27in FHD Monitor                 1      149.99
# 186847   176556      AAA Batteries (4-pack)                 3        2.99
# 186848   176557                      iPhone                 1      700.00
# 186849   176557    Lightning Charging Cable                 1       14.95
#
#             Order Date                           Purchase Address  Month  \
# 0       08/31/19 22:21           359 Spruce St, Seattle, WA 98101      8
# 1       08/15/19 15:11             492 Ridge St, Dallas, TX 75001      8
# 2       08/06/19 14:40             149 7th St, Portland, OR 97035      8
# 3       08/29/19 20:59          631 2nd St, Los Angeles, CA 90001      8
# 4       08/15/19 19:53       736 14th St, New York City, NY 10001      8
# ...                ...                                        ...    ...
# 186845  03/24/19 11:14       672 12th St, San Francisco, CA 94016      3
# 186846  03/22/19 20:27         42 4th St, San Francisco, CA 94016      3
# 186847  03/14/19 10:29          871 7th St, Los Angeles, CA 90001      3
# 186848  03/30/19 12:32  83 Washington St, San Francisco, CA 94016      3
# 186849  03/30/19 12:32  83 Washington St, San Francisco, CA 94016      3
#
#          Sales
# 0        23.98
# 1        99.99
# 2       700.00
# 3         7.68
# 4         7.68
# ...        ...
# 186845   14.95
# 186846  149.99
# 186847    8.97
# 186848  700.00
# 186849   14.95
#
# [185950 rows x 8 columns]

# %%
raw_data["Sales"] = raw_data['Quantity Ordered'] * raw_data['Price Each']
raw_data
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        236670            Wired Headphones                 2       11.99
# 1        236671  Bose SoundSport Headphones                 1       99.99
# 2        236672                      iPhone                 1      700.00
# 3        236673       AA Batteries (4-pack)                 2        3.84
# 4        236674       AA Batteries (4-pack)                 2        3.84
# ...         ...                         ...               ...         ...
# 186845   176554    Lightning Charging Cable                 1       14.95
# 186846   176555            27in FHD Monitor                 1      149.99
# 186847   176556      AAA Batteries (4-pack)                 3        2.99
# 186848   176557                      iPhone                 1      700.00
# 186849   176557    Lightning Charging Cable                 1       14.95
#
#             Order Date                           Purchase Address  Month  \
# 0       08/31/19 22:21           359 Spruce St, Seattle, WA 98101      8
# 1       08/15/19 15:11             492 Ridge St, Dallas, TX 75001      8
# 2       08/06/19 14:40             149 7th St, Portland, OR 97035      8
# 3       08/29/19 20:59          631 2nd St, Los Angeles, CA 90001      8
# 4       08/15/19 19:53       736 14th St, New York City, NY 10001      8
# ...                ...                                        ...    ...
# 186845  03/24/19 11:14       672 12th St, San Francisco, CA 94016      3
# 186846  03/22/19 20:27         42 4th St, San Francisco, CA 94016      3
# 186847  03/14/19 10:29          871 7th St, Los Angeles, CA 90001      3
# 186848  03/30/19 12:32  83 Washington St, San Francisco, CA 94016      3
# 186849  03/30/19 12:32  83 Washington St, San Francisco, CA 94016      3
#
#          Sales
# 0        23.98
# 1        99.99
# 2       700.00
# 3         7.68
# 4         7.68
# ...        ...
# 186845   14.95
# 186846  149.99
# 186847    8.97
# 186848  700.00
# 186849   14.95
#
# [185950 rows x 8 columns]

# %%
results = raw_data.groupby('Month').sum()

# %%
months = range(1,13)
plt.bar(months,results['Sales'])
plt.xticks(months)
plt.ylabel('Sales ($)')
plt.xlabel('Months')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
def get_city(address):
    return address.split(',')[1]

def get_city_code(address):
    return address.split(',')[2].split(' ')[1]

raw_data['City'] = raw_data['Purchase Address'].apply(lambda x: f"{get_city(x)} ({get_city_code(x)})")
raw_data
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        236670            Wired Headphones                 2       11.99
# 1        236671  Bose SoundSport Headphones                 1       99.99
# 2        236672                      iPhone                 1      700.00
# 3        236673       AA Batteries (4-pack)                 2        3.84
# 4        236674       AA Batteries (4-pack)                 2        3.84
# ...         ...                         ...               ...         ...
# 186845   176554    Lightning Charging Cable                 1       14.95
# 186846   176555            27in FHD Monitor                 1      149.99
# 186847   176556      AAA Batteries (4-pack)                 3        2.99
# 186848   176557                      iPhone                 1      700.00
# 186849   176557    Lightning Charging Cable                 1       14.95
#
#             Order Date                           Purchase Address  Month  \
# 0       08/31/19 22:21           359 Spruce St, Seattle, WA 98101      8
# 1       08/15/19 15:11             492 Ridge St, Dallas, TX 75001      8
# 2       08/06/19 14:40             149 7th St, Portland, OR 97035      8
# 3       08/29/19 20:59          631 2nd St, Los Angeles, CA 90001      8
# 4       08/15/19 19:53       736 14th St, New York City, NY 10001      8
# ...                ...                                        ...    ...
# 186845  03/24/19 11:14       672 12th St, San Francisco, CA 94016      3
# 186846  03/22/19 20:27         42 4th St, San Francisco, CA 94016      3
# 186847  03/14/19 10:29          871 7th St, Los Angeles, CA 90001      3
# 186848  03/30/19 12:32  83 Washington St, San Francisco, CA 94016      3
# 186849  03/30/19 12:32  83 Washington St, San Francisco, CA 94016      3
#
#          Sales                 City
# 0        23.98         Seattle (WA)
# 1        99.99          Dallas (TX)
# 2       700.00        Portland (OR)
# 3         7.68     Los Angeles (CA)
# 4         7.68   New York City (NY)
# ...        ...                  ...
# 186845   14.95   San Francisco (CA)
# 186846  149.99   San Francisco (CA)
# 186847    8.97     Los Angeles (CA)
# 186848  700.00   San Francisco (CA)
# 186849   14.95   San Francisco (CA)
#
# [185950 rows x 9 columns]

# %%
city_sales = raw_data.groupby('City').sum()
city_sales
# Out:
#                      Quantity Ordered    Price Each   Month         Sales
# City
#  Atlanta (GA)                   16602  2.779908e+06  104794  2.795499e+06
#  Austin (TX)                    11153  1.809874e+06   69829  1.819582e+06
#  Boston (MA)                    22528  3.637410e+06  141112  3.661642e+06
#  Dallas (TX)                    16730  2.752628e+06  104620  2.767975e+06
#  Los Angeles (CA)               33289  5.421435e+06  208325  5.452571e+06
#  New York City (NY)             27932  4.635371e+06  175741  4.664317e+06
#  Portland (ME)                   2750  4.471893e+05   17144  4.497583e+05
#  Portland (OR)                  11303  1.860558e+06   70621  1.870732e+06
#  San Francisco (CA)             50239  8.211462e+06  315520  8.262204e+06
#  Seattle (WA)                   16553  2.733296e+06  104941  2.747755e+06

# %%
city = raw_data['City'].unique()
city = [city for city,df in raw_data.groupby('City')]
plt.bar(city, city_sales['Sales'])
plt.xticks(city,rotation='vertical',size=8)
plt.ylabel('Sales ($)')
plt.xlabel('Cities')
plt.show()
